# %% [markdown]
# # Fake News Classification

# %%
import sys
from scipy.stats import uniform, randint

# %%
sys.path.append("../../")

from src.data.dataset import load_articles_dataset
from src.models import ml_classifier
from src.data.dataset import split_dataset
from src import utils

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset_df = load_articles_dataset()
# Out:
# Found cached dataset parquet (/home/dqmis/.cache/huggingface/datasets/GonzaloA___parquet/GonzaloA--fake_news-1fe2b42e1fa111c8/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
# 100%|██████████| 3/3 [00:00<00:00, 536.84it/s]

# %%
dataset_df
# Out:
#                                                     text  label
# 0      Maury is perhaps one of the trashiest shows on...      0
# 1      Yesterday, after the father of one of the UCLA...      0
# 2      MOSCOW (Reuters) - Russia on Wednesday warned ...      1
# 3      House Majority Whip Steve Scalise (R., La.) th...      0
# 4      It can be said that Late Show host Stephen Col...      0
# ...                                                  ...    ...
# 24348  WARSAW (Reuters) - The president of the Europe...      1
# 24349  AMSTERDAM/UNITED NATIONS (Reuters) - An inquir...      1
# 24350  As you may or may not know at this point, MSNB...      0
# 24351  WASHINGTON (Reuters) - U.S. President Donald T...      1
# 24352  KIEV (Reuters) - Ukrainian opposition leader Y...      1
#
# [24353 rows x 2 columns]

# %%
# Split into train and test
train_df, val_df, test_df = split_dataset(dataset_df)

# %%
train_df
# Out:
#                                                     text  label
# 15075  BERLIN (Reuters) - Germany would take advantag...      1
# 21575   Join Patrick every Wednesday at Independent T...      0
# 2782   TOKYO (Reuters) - A Japanese cosmetic surgeon ...      1
# 8713   There were a lot of memorable moments where Do...      0
# 17338  Amateur president Donald Trump met with Canadi...      0
# ...                                                  ...    ...
# 12787  HAMBURG (Reuters) - Leaders from the world’s l...      1
# 16251  Hillary Clinton continues on the path to compl...      0
# 23527  WASHINGTON (Reuters) - Four U.S. senators intr...      1
# 9085   top  amazing indigenous allnatural cures from ...      0
# 3866   WASHINGTON (Reuters) - Legislation expanding t...      1
#
# [17533 rows x 2 columns]

# %%
x_train, y_train = train_df["text"].values, train_df["label"].values
x_val, y_val = val_df["text"].values, val_df["label"].values
x_test, y_test = test_df["text"].values, test_df["label"].values

# %% [markdown]
# Let's train and evaluate logistic regression model.

# %%
# Logreg model
model = ml_classifier.MlClassifier(classifier_name="logreg")
model.fit(x_train, y_train)

# Calculate metrics
y_pred = model.predict(x_test)

for metric, value in utils.evaluate_model(y_test, y_pred).items():
    print(f"{metric}: {value}")

model.get_feature_importance()
# Out:
# /home/dqmis/projects/nlp-classification/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# f1: 0.9810163688978402
# accuracy: 0.9811127078628619
# classification_report:               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      2248
#            1       0.99      0.98      0.98      2623
#
#     accuracy                           0.98      4871
#    macro avg       0.98      0.98      0.98      4871
# weighted avg       0.98      0.98      0.98      4871
# ...

# %% [markdown]
# ## After removing strong feature

# %%
dataset_df = load_articles_dataset(process=True)
train_df, val_df, test_df = split_dataset(dataset_df)

x_train, y_train = train_df["text"].values, train_df["label"].values
x_val, y_val = val_df["text"].values, val_df["label"].values
x_test, y_test = test_df["text"].values, test_df["label"].values

# Logreg model
model = ml_classifier.MlClassifier(classifier_name="logreg")
model.fit(x_train, y_train)

# Calculate metrics
y_pred = model.predict(x_test)

for metric, value in utils.evaluate_model(y_test, y_pred).items():
    print(f"{metric}: {value}")

model.get_feature_importance()
# Out:
# Found cached dataset parquet (/home/dqmis/.cache/huggingface/datasets/GonzaloA___parquet/GonzaloA--fake_news-1fe2b42e1fa111c8/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
# 100%|██████████| 3/3 [00:00<00:00, 495.02it/s]
# /home/dqmis/projects/nlp-classification/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# f1: 0.9626040306841289
# accuracy: 0.9628413056867173
# classification_report:               precision    recall  f1-score   support
#
# ...
